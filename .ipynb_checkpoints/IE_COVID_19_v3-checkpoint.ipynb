# %% [markdown]
# <img src="profile_manoelgadi.png" width=100 height=100 align="right">
#
# Author: Prof. Manoel Gadi
#
# Contact: mfalonso@faculty.ie.edu
#
# Teaching Web: http://mfalonso.pythonanywhere.com
#
# Last revision: 09/April/2020

# %% [markdown]
# # Doing some graphs

# %%
import pandas as pd

# Load CSV data directly from the URL with pandas
data = pd.read_csv('https://open-covid-19.github.io/data/data.csv')
data['Date'] = data['Date'].apply(lambda x: pd.to_datetime(str(x), format='%Y-%m-%d'))
import datetime
datetime.date.today()

data = data[data['Date']<datetime.date.today()]
data.head()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   if __name__ == '__main__':
#         Date Key CountryCode           CountryName RegionCode RegionName  \
# 0 2019-12-31  AE          AE  United Arab Emirates        NaN        NaN
# 1 2019-12-31  AF          AF           Afghanistan        NaN        NaN
# 2 2019-12-31  AM          AM               Armenia        NaN        NaN
# 3 2019-12-31  AT          AT               Austria        NaN        NaN
# 4 2019-12-31  AU          AU             Australia        NaN        NaN
#
#    Confirmed  Deaths   Latitude   Longitude  Population
# 0        0.0     0.0  23.424076   53.847818   9770529.0
# 1        0.0     0.0  33.939110   67.709953  38041754.0
# 2        0.0     0.0  40.069099   45.038189   2957731.0
# 3        0.0     0.0  47.516231   14.550072   8955102.0
# 4        0.0     0.0 -25.274398  133.775136  25203198.0

# %%
confirmed_df = data[data['Date']==data['Date'].max()].fillna(0)
confirmed_df.head()
# Out:
#             Date Key CountryCode           CountryName RegionCode RegionName  \
# 27698 2020-04-08  AD          AD               Andorra          0          0
# 27699 2020-04-08  AE          AE  United Arab Emirates          0          0
# 27700 2020-04-08  AF          AF           Afghanistan          0          0
# 27701 2020-04-08  AG          AG   Antigua and Barbuda          0          0
# 27702 2020-04-08  AI          AI              Anguilla          0          0
#
#        Confirmed  Deaths   Latitude  Longitude  Population
# 27698      545.0    22.0  42.546245   1.601554     77142.0
# 27699     2359.0    12.0  23.424076  53.847818   9770529.0
# 27700      367.0    11.0  33.939110  67.709953  38041754.0
# 27701       15.0     0.0  17.060816 -61.796428     97118.0
# 27702        3.0     0.0  18.220554 -63.068615     14869.0

# %%
confirmed_df['Deaths'].iloc[0]
# Out:
# 22.0

# %%
# creating world map using Map class
import folium
import numpy as np

world_map = folium.Map(location=[11,0], tiles="cartodbpositron", zoom_start=2, max_zoom = 6, min_zoom = 2)
# iterate over all the rows of confirmed_df to get the lat/long
for i in range(0,len(confirmed_df)):
    folium.Circle(
        location=[confirmed_df.iloc[i]['Latitude'], confirmed_df.iloc[i]['Longitude']],
        fill=True,
        radius=(int((np.log(confirmed_df['Deaths'].iloc[i]+1.00001)))+0.2)*50000,
        color='red',
        fill_color='indigo',
    ).add_to(world_map)
    
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Shall we be scared?

# %% [markdown]
# Before carying on, let's understand a litle bit about the virus.
#
# https://ourworldindata.org/kurzgesagt-coronavirus-video

# %% [markdown]
# ## Now, let's analyse the data.

# %%
import pandas as pd

# Load CSV data directly from the URL with pandas
data = pd.read_csv('https://open-covid-19.github.io/data/data.csv')

# Alternatively load the JSON data, which should be identical
data_json = pd.read_json('https://open-covid-19.github.io/data/data.json')
assert len(data) == len(data_json)

# Print a small snippet of the dataset
print('The dataset currently contains %d records, here are the last few:' % len(data))
data.tail()
# Out:
# The dataset currently contains 28411 records, here are the last few:
#              Date    Key CountryCode CountryName RegionCode RegionName  \
# 28406  2020-04-09  JP_28          JP       Japan         28      Hyōgo
# 28407  2020-04-09  JP_33          JP       Japan         33    Okayama
# 28408  2020-04-09  JP_38          JP       Japan         38      Ehime
# 28409  2020-04-09  JP_39          JP       Japan         39      Kōchi
# 28410  2020-04-09  JP_47          JP       Japan         47    Okinawa
#
#        Confirmed  Deaths   Latitude   Longitude  Population
# 28406      267.0     NaN  34.690817  135.183078   5469762.0
# 28407       15.0     NaN  34.700000  133.850000   1906464.0
# 28408       26.0     NaN  33.833000  132.833000   1342011.0
# 28409       49.0     NaN  33.433000  133.433000    757914.0
# 28410       42.0     NaN  26.500000  128.000000   1457162.0

# %%
data['Date'] = data['Date'].apply(lambda x: pd.to_datetime(str(x), format='%Y-%m-%d'))

# %%
import datetime
datetime.date.today()
# Out:
# datetime.date(2020, 4, 9)

# %%
len(data)
# Out:
# 28411

# %%
data = data[data['Date']<datetime.date.today()]
data.head()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """Entry point for launching an IPython kernel.
#         Date Key CountryCode           CountryName RegionCode RegionName  \
# 0 2019-12-31  AE          AE  United Arab Emirates        NaN        NaN
# 1 2019-12-31  AF          AF           Afghanistan        NaN        NaN
# 2 2019-12-31  AM          AM               Armenia        NaN        NaN
# 3 2019-12-31  AT          AT               Austria        NaN        NaN
# 4 2019-12-31  AU          AU             Australia        NaN        NaN
#
#    Confirmed  Deaths   Latitude   Longitude  Population
# 0        0.0     0.0  23.424076   53.847818   9770529.0
# 1        0.0     0.0  33.939110   67.709953  38041754.0
# 2        0.0     0.0  40.069099   45.038189   2957731.0
# 3        0.0     0.0  47.516231   14.550072   8955102.0
# 4        0.0     0.0 -25.274398  133.775136  25203198.0

# %%
len(data)
# Out:
# 28375

# %% [markdown]
# ## Filter records that have the right country code AND a non-null region code

# %%
spain_regions = data[(data['CountryCode'] == 'ES') & ~(data['RegionCode'].isna())]

spain_regions.sort_values(by = 'Date', ascending = False).head(10)
# Out:
#             Date    Key CountryCode CountryName RegionCode  \
# 27924 2020-04-08  ES_VC          ES       Spain         VC
# 27915 2020-04-08  ES_EX          ES       Spain         EX
# 27906 2020-04-08  ES_AN          ES       Spain         AN
# 27907 2020-04-08  ES_AR          ES       Spain         AR
# 27908 2020-04-08  ES_AS          ES       Spain         AS
# 27909 2020-04-08  ES_CB          ES       Spain         CB
# 27910 2020-04-08  ES_CE          ES       Spain         CE
# 27912 2020-04-08  ES_CM          ES       Spain         CM
# 27913 2020-04-08  ES_CN          ES       Spain         CN
# 27914 2020-04-08  ES_CT          ES       Spain         CT
#
#                  RegionName  Confirmed  Deaths  Latitude  Longitude  \
# 27924  Comunidad Valenciana     7655.0   724.0   39.4697    -0.3774
# 27915           Extremadura     2184.0   271.0   38.9161    -6.3436
# 27906             Andalucía     8997.0   605.0   37.3828    -5.9731
# 27907                Aragón     3549.0   349.0   41.6560    -0.8773
# 27908              Asturias     1705.0   102.0   43.3602    -5.8447
# 27909             Cantabria     1572.0    92.0   43.4647    -3.8044
# 27910                 Ceuta       84.0     4.0   35.8893    -5.3198
# 27912    Castilla-La Mancha    11788.0  1255.0   39.8628    -4.0273
# 27913        Islas Canarias     1762.0    91.0   28.4682   -16.2546
# 27914              Cataluña    29647.0  3041.0   41.3887     2.1590
#
#        Population
# 27924   5003769.0
# 27915   1087778.0
# 27906   8388107.0
# 27907   1308563.0
# 27908   1022800.0
# 27909    580229.0
# 27910     85144.0
# 27912   2041631.0
# 27913   2153389.0
# 27914   7522596.0

# %% [markdown]
# ## Spain Accumulated Deaths

# %%
data.Date.value_counts().head()
# Out:
# 2020-04-07    734
# 2020-04-03    733
# 2020-04-06    732
# 2020-04-01    722
# 2020-04-04    720
# Name: Date, dtype: int64

# %%
spain_acc_deaths = spain_regions[['CountryName','Date','Deaths']].groupby(['CountryName','Date']) \
                             .sum().sort_values(by = ['Date'], ascending = False)

# %%
spain_acc_deaths.head()
# Out:
#                          Deaths
# CountryName Date
# Spain       2020-04-08  14555.0
#             2020-04-07  13798.0
#             2020-04-06  13055.0
#             2020-04-05  12418.0
#             2020-04-04  11744.0

# %%
spain_acc_deaths_asc = spain_regions[['CountryName','Date','Deaths']].groupby(['CountryName','Date']) \
                             .sum().sort_values(by = ['Date'], ascending = True)

# %%
# %matplotlib inline

# %%
spain_acc_deaths_asc.plot(kind='bar', figsize=(16, 4));

# %% [markdown]
# ## Spain Daily Deaths

# %%
spain_daily_deaths = spain_acc_deaths.loc[:,'Deaths']-spain_acc_deaths.loc[:,'Deaths'].shift(-1)

# %%
spain_daily_deaths.head()
# Out:
# CountryName  Date
# Spain        2020-04-08    757.0
#              2020-04-07    743.0
#              2020-04-06    637.0
#              2020-04-05    674.0
#              2020-04-04    809.0
# Name: Deaths, dtype: float64

# %%
spain_daily_deaths_asc = spain_acc_deaths_asc.loc[:,'Deaths']-spain_acc_deaths_asc.loc[:,'Deaths'].shift(1)

# %%
spain_daily_deaths_asc.plot(kind='bar', figsize=(16, 4));

# %% [markdown]
# ---

# %% [markdown]
# # Looking at the outbreak
#
# There are months of data, but we only care about when the number of cases started to grow. We define outbreak as whenever the number of cases exceeded certain threshold and for data quality we remove data without Region associated. In this case, we are using 5 Deaths.

# %% [markdown]
# ## Grouping all data by country (not regions)

# %%
data_bkp = data.copy()

# %% [markdown]
# ---

# %%
data = data_bkp.copy()

# %%
data = data[~(data['RegionCode'].isna())]

# %%
data = data[['CountryName','Date','Confirmed','Deaths']].groupby(['CountryName','Date']) \
                             .sum().sort_values(by = ['Date'], ascending = False)
data
# Out:
#                                      Confirmed   Deaths
# CountryName              Date
# United States of America 2020-04-08   422363.0  14464.0
# Sweden                   2020-04-08     7783.0    619.0
# Spain                    2020-04-08   146690.0  14555.0
# South Korea              2020-04-08     8249.0    165.0
# China                    2020-04-08    75449.0   3274.0
# Russia                   2020-04-08     8248.0      0.0
# Portugal                 2020-04-08    13141.0    380.0
# Australia                2020-04-08     6024.0     50.0
# Poland                   2020-04-08     5056.0      0.0
# Germany                  2020-04-08   110355.0   2151.0
# Bolivia                  2020-04-08      244.0      8.0
# Pakistan                 2020-04-08     4124.0      0.0
# Canada                   2020-04-08    19261.0    435.0
# Norway                   2020-04-08     6009.0      0.0
# Mexico                   2020-04-08     3181.0    174.0
# Malaysia                 2020-04-08     4119.0    156.0
# Japan                    2020-04-08     4705.0      0.0
# Brazil                   2020-04-08    15927.0    800.0
# France                   2020-04-08        0.0   7632.0
# Italy                    2020-04-08   139422.0  17669.0
# India                    2020-04-08     4352.0     92.0
# Argentina                2020-04-08     1314.0     66.0
# Colombia                 2020-04-08     2281.0      3.0
# United Kingdom           2020-04-08     9977.0    689.0
# Switzerland              2020-04-08    13892.0    541.0
# Chile                    2020-04-07     4959.0      0.0
# Russia                   2020-04-07     6993.0      0.0
# Portugal                 2020-04-07    12442.0    345.0
# Australia                2020-04-07     5919.0     48.0
# Colombia                 2020-04-07     1879.0      2.0
# ...                                        ...      ...
# France                   2020-01-28        4.0      0.0
# United Kingdom           2020-01-28        0.0      0.0
# France                   2020-01-27        3.0      0.0
# China                    2020-01-27     2798.0     81.0
# Mexico                   2020-01-27        0.0      0.0
# South Korea              2020-01-27        2.0      0.0
# United Kingdom           2020-01-27        0.0      0.0
#                          2020-01-26        0.0      0.0
# France                   2020-01-26        3.0      0.0
# China                    2020-01-26     2011.0     56.0
# Japan                    2020-01-26        1.0      0.0
# South Korea              2020-01-26        1.0      0.0
# Mexico                   2020-01-26        0.0      0.0
#                          2020-01-25        0.0      0.0
# United Kingdom           2020-01-25        0.0      0.0
# Malaysia                 2020-01-25        4.0      0.0
# Japan                    2020-01-25        2.0      0.0
# France                   2020-01-25        3.0      0.0
# China                    2020-01-25     1347.0     41.0
# France                   2020-01-24        3.0      0.0
# China                    2020-01-24      882.0     26.0
# South Korea              2020-01-24        1.0      0.0
# Mexico                   2020-01-24        0.0      0.0
# United Kingdom           2020-01-24        0.0      0.0
# Japan                    2020-01-24        1.0      0.0
# China                    2020-01-23      609.0     17.0
# Mexico                   2020-01-23        0.0      0.0
# China                    2020-01-22      458.0      9.0
# South Korea              2020-01-20        1.0      0.0
# Japan                    2020-01-15        1.0      0.0
#
# [1200 rows x 2 columns]

# %%
def get_outbreak_mask(data: pd.DataFrame, threshold: int = 10, concept: str = 'Confirmed'):
    ''' Returns a mask for > N confirmed cases '''
    return (data[concept] > threshold) 

cols = ['CountryCode', 'CountryName', 'Confirmed', 'Deaths']
# Get data only after the outbreak begun
data = data[get_outbreak_mask(data,threshold=5,concept='Deaths')]

data.head()
# Out:
#                                      Confirmed   Deaths
# CountryName              Date
# United States of America 2020-04-08   422363.0  14464.0
# Sweden                   2020-04-08     7783.0    619.0
# Spain                    2020-04-08   146690.0  14555.0
# South Korea              2020-04-08     8249.0    165.0
# China                    2020-04-08    75449.0   3274.0

# %%
data = data.sort_values(['CountryName','Date'], ascending = (True, True))
data.head()
# Out:
#                         Confirmed  Deaths
# CountryName Date
# Argentina   2020-03-24      426.0     6.0
#             2020-03-25      559.0     8.0
#             2020-03-26      676.0    12.0
#             2020-03-27      762.0    11.0
#             2020-03-28      816.0    19.0

# %%
data.to_csv("cov19.csv")

# %% [markdown]
# # Part 2

# %%
import pandas as pd
# %matplotlib inline
data = pd.read_csv("cov19.csv")

# %%
data.head()
# Out:
#   CountryName        Date  Confirmed  Deaths
# 0   Argentina  2020-03-24      426.0     6.0
# 1   Argentina  2020-03-25      559.0     8.0
# 2   Argentina  2020-03-26      676.0    12.0
# 3   Argentina  2020-03-27      762.0    11.0
# 4   Argentina  2020-03-28      816.0    19.0

# %% [markdown]
# ## Calculating Daily Changes

# %%
import numpy as np
np.nan
# Out:
# nan

# %%
data["DailyDeaths"]  = data.loc[:,'Deaths']-data.loc[:,'Deaths'].shift(1)

# %%
data.loc[~(data['CountryName'] == data['CountryName'].shift(1)),"DailyDeaths"] = np.nan

# %%
data.head()
# Out:
#   CountryName        Date  Confirmed  Deaths  DailyDeaths
# 0   Argentina  2020-03-24      426.0     6.0          NaN
# 1   Argentina  2020-03-25      559.0     8.0          2.0
# 2   Argentina  2020-03-26      676.0    12.0          4.0
# 3   Argentina  2020-03-27      762.0    11.0         -1.0
# 4   Argentina  2020-03-28      816.0    19.0          8.0

# %%
data["DailyConfirmed"]  = data.loc[:,'Confirmed']-data.loc[:,'Confirmed'].shift(1)

# %%
data.loc[~(data['CountryName'] == data['CountryName'].shift(1)),"DailyConfirmed"] = np.nan

# %%
data.head()
# Out:
#   CountryName        Date  Confirmed  Deaths  DailyDeaths  DailyConfirmed
# 0   Argentina  2020-03-24      426.0     6.0          NaN             NaN
# 1   Argentina  2020-03-25      559.0     8.0          2.0           133.0
# 2   Argentina  2020-03-26      676.0    12.0          4.0           117.0
# 3   Argentina  2020-03-27      762.0    11.0         -1.0            86.0
# 4   Argentina  2020-03-28      816.0    19.0          8.0            54.0

# %% [markdown]
# ---

# %% [markdown]
# ## Vintage or Cohort Analysis
#
# ### Analysing all countris starting from the first outbreak day 0

# %%
data[['CountryName','Date']].groupby(['CountryName']).min().head()
# Out:
#                    Date
# CountryName
# Argentina    2020-03-24
# Australia    2020-03-22
# Bolivia      2020-03-30
# Brazil       2020-03-19
# Canada       2020-03-20

# %%
outbreak_day0 = data[['CountryName','Date']]

# %%
outbreak_day0.columns = ['CountryName','OutbreakStartDate']

# %%
outbreak_day0 = outbreak_day0[['CountryName','OutbreakStartDate']].groupby(['CountryName']).min()

# %%
outbreak_day0.head()
# Out:
#             OutbreakStartDate
# CountryName
# Argentina          2020-03-24
# Australia          2020-03-22
# Bolivia            2020-03-30
# Brazil             2020-03-19
# Canada             2020-03-20

# %%
pd.merge(data, outbreak_day0, how='left', left_on='CountryName', right_on='CountryName').head()
# Out:
#   CountryName        Date  Confirmed  Deaths  DailyDeaths  DailyConfirmed  \
# 0   Argentina  2020-03-24      426.0     6.0          NaN             NaN
# 1   Argentina  2020-03-25      559.0     8.0          2.0           133.0
# 2   Argentina  2020-03-26      676.0    12.0          4.0           117.0
# 3   Argentina  2020-03-27      762.0    11.0         -1.0            86.0
# 4   Argentina  2020-03-28      816.0    19.0          8.0            54.0
#
#   OutbreakStartDate
# 0        2020-03-24
# 1        2020-03-24
# 2        2020-03-24
# 3        2020-03-24
# 4        2020-03-24

# %%
df = pd.merge(data, outbreak_day0, how='left', left_on='CountryName', right_on='CountryName')

# %%
df.dtypes
# Out:
# CountryName           object
# Date                  object
# Confirmed            float64
# Deaths               float64
# DailyDeaths          float64
# DailyConfirmed       float64
# OutbreakStartDate     object
# dtype: object

# %%
df['Date'] = df['Date'].apply(lambda x: pd.to_datetime(str(x), format='%Y-%m-%d'))

# %%
df['OutbreakStartDate'] = df['OutbreakStartDate'].apply(lambda x: pd.to_datetime(str(x), format='%Y-%m-%d'))

# %%
df.dtypes
# Out:
# CountryName                  object
# Date                 datetime64[ns]
# Confirmed                   float64
# Deaths                      float64
# DailyDeaths                 float64
# DailyConfirmed              float64
# OutbreakStartDate    datetime64[ns]
# dtype: object

# %%
(df['Date'] - df['OutbreakStartDate']).head()
# Out:
# 0   0 days
# 1   1 days
# 2   2 days
# 3   3 days
# 4   4 days
# dtype: timedelta64[ns]

# %%
df['day']=(df['Date'] - df['OutbreakStartDate'])

# %%
df['day'] = df['day'].dt.days.astype('int16')

# %%
df['day'].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: day, dtype: int16

# %%
df.head()
# Out:
#   CountryName       Date  Confirmed  Deaths  DailyDeaths  DailyConfirmed  \
# 0   Argentina 2020-03-24      426.0     6.0          NaN             NaN
# 1   Argentina 2020-03-25      559.0     8.0          2.0           133.0
# 2   Argentina 2020-03-26      676.0    12.0          4.0           117.0
# 3   Argentina 2020-03-27      762.0    11.0         -1.0            86.0
# 4   Argentina 2020-03-28      816.0    19.0          8.0            54.0
#
#   OutbreakStartDate  day
# 0        2020-03-24    0
# 1        2020-03-24    1
# 2        2020-03-24    2
# 3        2020-03-24    3
# 4        2020-03-24    4

# %%
df.tail()
# Out:
#                   CountryName       Date  Confirmed   Deaths  DailyDeaths  \
# 512  United States of America 2020-04-04   305162.0   8291.0       1349.0
# 513  United States of America 2020-04-05   331671.0   9472.0       1181.0
# 514  United States of America 2020-04-06   360654.0  10653.0       1181.0
# 515  United States of America 2020-04-07   391849.0  12591.0       1938.0
# 516  United States of America 2020-04-08   422363.0  14464.0       1873.0
#
#      DailyConfirmed OutbreakStartDate  day
# 512         33682.0        2020-03-04   31
# 513         26509.0        2020-03-04   32
# 514         28983.0        2020-03-04   33
# 515         31195.0        2020-03-04   34
# 516         30514.0        2020-03-04   35

# %%
#df.index = df.day

# %%
# plot data
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
df.groupby(['day','CountryName']).sum()['Deaths'].unstack().plot(ax=ax)

# %% [markdown]
# # The ratio Confirmed / Death

# %%
df_germany = df[df['CountryName'] == 'Germany']
df_germany
# Out:
#     CountryName       Date  Confirmed  Deaths  DailyDeaths  DailyConfirmed  \
# 204     Germany 2020-03-17     9348.0    24.0          NaN             NaN
# 205     Germany 2020-03-18    12223.0    36.0         12.0          2875.0
# 206     Germany 2020-03-19    15240.0    43.0          7.0          3017.0
# 207     Germany 2020-03-20    19712.0    64.0         21.0          4472.0
# 208     Germany 2020-03-21    22101.0    81.0         17.0          2389.0
# 209     Germany 2020-03-22    24273.0    92.0         11.0          2172.0
# 210     Germany 2020-03-23    28942.0   122.0         30.0          4669.0
# 211     Germany 2020-03-24    33856.0   144.0         22.0          4914.0
# 212     Germany 2020-03-25    37949.0   181.0         37.0          4093.0
# 213     Germany 2020-03-26    43938.0   261.0         80.0          5989.0
# 214     Germany 2020-03-27    50871.0   351.0         90.0          6933.0
# 215     Germany 2020-03-28    56517.0   423.0         72.0          5646.0
# 216     Germany 2020-03-29    61164.0   490.0         67.0          4647.0
# 217     Germany 2020-03-30    64950.0   597.0        107.0          3786.0
# 218     Germany 2020-04-01    71571.0   746.0        149.0          6621.0
# 219     Germany 2020-04-02    81221.0  1033.0        287.0          9650.0
# 220     Germany 2020-04-03    90166.0  1206.0        173.0          8945.0
# 221     Germany 2020-04-04    94870.0  1398.0        192.0          4704.0
# 222     Germany 2020-04-05    99513.0  1521.0        123.0          4643.0
# 223     Germany 2020-04-06   101122.0  1683.0        162.0          1609.0
# 224     Germany 2020-04-07   103483.0  1823.0        140.0          2361.0
# 225     Germany 2020-04-08   110355.0  2151.0        328.0          6872.0
#
#     OutbreakStartDate  day
# 204        2020-03-17    0
# 205        2020-03-17    1
# 206        2020-03-17    2
# 207        2020-03-17    3
# 208        2020-03-17    4
# 209        2020-03-17    5
# 210        2020-03-17    6
# 211        2020-03-17    7
# 212        2020-03-17    8
# 213        2020-03-17    9
# 214        2020-03-17   10
# 215        2020-03-17   11
# 216        2020-03-17   12
# 217        2020-03-17   13
# 218        2020-03-17   15
# 219        2020-03-17   16
# 220        2020-03-17   17
# 221        2020-03-17   18
# 222        2020-03-17   19
# 223        2020-03-17   20
# 224        2020-03-17   21
# 225        2020-03-17   22

# %%
df_germany['Confirmed']/df_germany['Deaths']
# Out:
# 204    389.500000
# 205    339.527778
# 206    354.418605
# 207    308.000000
# 208    272.851852
# 209    263.836957
# 210    237.229508
# 211    235.111111
# 212    209.662983
# 213    168.344828
# 214    144.931624
# 215    133.609929
# 216    124.824490
# 217    108.793970
# 218     95.939678
# 219     78.626331
# 220     74.764511
# 221     67.861230
# 222     65.426036
# 223     60.084373
# 224     56.765222
# 225     51.304045
# dtype: float64

# %% [markdown]
# ### Some moving average variables

# %%
df = df.sort_values(['CountryName','day'], ascending = (True, True))

# %%
# Group df by df.platoon, then apply a rolling mean lambda function to df.casualties
df['DailyDeaths_MA_3'] = df.groupby('CountryName')['DailyDeaths'].apply(lambda x:x.rolling(center=False,window=3).mean())
df['DailyDeaths_MA_7'] = df.groupby('CountryName')['DailyDeaths'].apply(lambda x:x.rolling(center=False,window=7).mean())
df['DailyDeaths_MA_14'] = df.groupby('CountryName')['DailyDeaths'].apply(lambda x:x.rolling(center=False,window=14).mean())
df['DailyDeaths_MA_21'] = df.groupby('CountryName')['DailyDeaths'].apply(lambda x:x.rolling(center=False,window=21).mean())

# %%
df[['day','CountryName','DailyDeaths_MA_3','DailyDeaths_MA_7','DailyDeaths_MA_14','DailyDeaths_MA_21']].head()
# Out:
#    day CountryName  DailyDeaths_MA_3  DailyDeaths_MA_7  DailyDeaths_MA_14  \
# 0    0   Argentina               NaN               NaN                NaN
# 1    1   Argentina               NaN               NaN                NaN
# 2    2   Argentina               NaN               NaN                NaN
# 3    3   Argentina          1.666667               NaN                NaN
# 4    4   Argentina          3.666667               NaN                NaN
#
#    DailyDeaths_MA_21
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# ## Analysing China, Italy and Spain

# %%
#pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.1f' % x)

# %%
country = 'China'
df_single_country = df[df['CountryName']==country]
print(country)
list_vars = ['CountryName','day','DailyDeaths','DailyDeaths_MA_3','DailyDeaths_MA_7','DailyDeaths_MA_14','DailyDeaths_MA_21']
df_single_country[list_vars].set_index('day').plot();
df_single_country[list_vars][30:40]
# Out:
# China
#     CountryName  day  DailyDeaths  DailyDeaths_MA_3  DailyDeaths_MA_7  \
# 108       China   30        118.0             122.7             122.6
# 109       China   31        106.0             112.0             117.4
# 110       China   32         94.0             106.0             110.4
# 111       China   33        157.0             119.0             118.0
# 112       China   34         70.0             107.0             113.6
# 113       China   35         45.0              90.7             100.3
# 114       China   36         36.0              50.3              89.4
# 115       China   37         42.0              41.0              78.6
# 116       China   38         42.0              40.0              69.4
# 117       China   39         38.0              40.7              61.4
#
#      DailyDeaths_MA_14  DailyDeaths_MA_21
# 108              114.5               96.5
# 109              115.9               99.3
# 110              116.2              101.7
# 111              120.6              106.4
# 112              117.9              106.7
# 113              114.1              105.7
# 114               98.6              104.0
# 115              100.6              102.5
# 116               93.4              100.4
# 117               85.9               98.0

# %%
country = 'Italy'
df_single_country = df[df['CountryName']==country]
print(country)
list_vars = ['CountryName','day','DailyDeaths','DailyDeaths_MA_3','DailyDeaths_MA_7','DailyDeaths_MA_14','DailyDeaths_MA_21']
df_single_country[list_vars].set_index('day').plot();
df_single_country[list_vars][30:40]
# Out:
# Italy
#     CountryName  day  DailyDeaths  DailyDeaths_MA_3  DailyDeaths_MA_7  \
# 270       Italy   30        683.0             675.7             646.4
# 271       Italy   31        662.0             696.0             680.0
# 272       Italy   32        969.0             771.3             728.9
# 273       Italy   33        889.0             840.0             742.6
# 274       Italy   34        756.0             871.3             757.6
# 275       Italy   35        812.0             819.0             787.7
# 276       Italy   36        837.0             801.7             801.1
# 277       Italy   37        727.0             792.0             807.4
# 278       Italy   38        760.0             774.7             821.4
# 279       Italy   39        766.0             751.0             792.4
#
#      DailyDeaths_MA_14  DailyDeaths_MA_21
# 270              476.9              352.2
# 271              510.6              381.8
# 272              562.0              425.6
# 273              613.0              466.2
# 274              640.7              495.9
# 275              673.8              529.9
# 276              708.9              561.8
# 277              726.9              587.0
# 278              750.7              614.2
# 279              760.6              638.8

# %%
country = 'Spain'
df_single_country = df[df['CountryName']==country]
print(country)
list_vars = ['CountryName','day','DailyDeaths','DailyDeaths_MA_3','DailyDeaths_MA_7','DailyDeaths_MA_14','DailyDeaths_MA_21']
df_single_country[list_vars].set_index('day').plot();
df_single_country[list_vars][30:40]
# Out:
# Spain
#     CountryName  day  DailyDeaths  DailyDeaths_MA_3  DailyDeaths_MA_7  \
# 408       Spain   30        637.0             706.7             816.4
# 409       Spain   31        743.0             684.7             801.3
# 410       Spain   32        757.0             712.3             786.0
#
#      DailyDeaths_MA_14  DailyDeaths_MA_21
# 408              776.6              607.0
# 409              793.0              633.7
# 410              794.4              664.6

# %% [markdown]
# ---

# %% [markdown]
# # Automating the analysis for all countries in the dataset

# %%
df['CountryName'].unique()
# Out:
# array(['Argentina', 'Australia', 'Bolivia', 'Brazil', 'Canada', 'China',
#        'Colombia', 'France', 'Germany', 'India', 'Italy', 'Malaysia',
#        'Mexico', 'Portugal', 'South Korea', 'Spain', 'Sweden',
#        'Switzerland', 'United Kingdom', 'United States of America'],
#       dtype=object)

# %%
def func_analyse_single_country(country):
    df_single_country = df[df['CountryName']==country]
    print(country)
    list_vars = ['CountryName','day','DailyDeaths','DailyDeaths_MA_3','DailyDeaths_MA_7','DailyDeaths_MA_14','DailyDeaths_MA_21']
    df_single_country[list_vars].set_index('day').plot();
    return df_single_country[['Date']+list_vars].tail()

# %%
func_analyse_single_country(country = 'China')
# Out:
# China
#           Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 151 2020-04-04       China   73        -10.0              10.0
# 152 2020-04-05       China   74         12.0               1.0
# 153 2020-04-06       China   75         20.0               7.3
# 154 2020-04-07       China   76        -16.0               5.3
# 155 2020-04-08       China   77         -7.0              -1.0
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 151               4.1                6.3                5.0
# 152               4.0                5.2                6.5
# 153               7.9                4.1                6.9
# 154               7.3                3.6                5.0
# 155               5.6                4.5                5.0

# %%
func_analyse_single_country(country = 'Italy')
# Out:
# Italy
#           Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 280 2020-04-04       Italy   40        681.0             735.7
# 281 2020-04-05       Italy   41        525.0             657.3
# 282 2020-04-06       Italy   42        636.0             614.0
# 283 2020-04-07       Italy   43        604.0             588.3
# 284 2020-04-08       Italy   44        542.0             594.0
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 280             762.7              752.6              662.9
# 281             729.7              743.6              670.4
# 282             704.6              746.1              684.0
# 283             671.3              736.2              696.4
# 284             644.9              726.1              699.6

# %% [markdown]
# # Spain

# %%
func_analyse_single_country(country = 'Spain')
# Out:
# Spain
#           Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 406 2020-04-04       Spain   28        809.0             897.0
# 407 2020-04-05       Spain   29        674.0             805.0
# 408 2020-04-06       Spain   30        637.0             706.7
# 409 2020-04-07       Spain   31        743.0             684.7
# 410 2020-04-08       Spain   32        757.0             712.3
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 406             864.9              744.1              552.8
# 407             841.4              764.1              577.6
# 408             816.4              776.6              607.0
# 409             801.3              793.0              633.7
# 410             786.0              794.4              664.6

# %%
func_analyse_single_country(country = 'Argentina')
# Out:
# Argentina
#          Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 11 2020-04-04   Argentina   11          1.0               3.3
# 12 2020-04-05   Argentina   12          3.0               3.0
# 13 2020-04-06   Argentina   13          8.0               4.0
# 14 2020-04-07   Argentina   14          7.0               6.0
# 15 2020-04-08   Argentina   15          5.0               6.7
#
#     DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 11               3.4                nan                nan
# 12               3.6                nan                nan
# 13               4.4                nan                nan
# 14               4.9                3.9                nan
# 15               4.7                4.1                nan

# %%
func_analyse_single_country(country = 'Bolivia')
# Out:
# Bolivia
#          Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 34 2020-03-30     Bolivia    0          nan               nan
# 35 2020-04-06     Bolivia    7          3.0               nan
# 36 2020-04-08     Bolivia    9         -1.0               nan
#
#     DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 34               nan                nan                nan
# 35               nan                nan                nan
# 36               nan                nan                nan

# %%
func_analyse_single_country(country = 'Colombia')
# Out:
# Colombia
#           Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 164 2020-04-01    Colombia    9          7.0               2.0
# 165 2020-04-02    Colombia   10          2.0              -3.3
# 166 2020-04-03    Colombia   11         16.0               8.3
# 167 2020-04-04    Colombia   12         -7.0               3.7
# 168 2020-04-05    Colombia   13          4.0               4.3
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 164               1.0                nan                nan
# 165               1.3                nan                nan
# 166               3.1                nan                nan
# 167               1.4                nan                nan
# 168               3.0                nan                nan

# %%
func_analyse_single_country(country = 'Mexico')
# Out:
# Mexico
#           Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 320 2020-04-04      Mexico   10         19.0              14.0
# 321 2020-04-05      Mexico   11         15.0              14.7
# 322 2020-04-06      Mexico   12         31.0              21.7
# 323 2020-04-07      Mexico   13         16.0              20.7
# 324 2020-04-08      Mexico   14         33.0              26.7
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 320               9.0                nan                nan
# 321              10.6                nan                nan
# 322              13.9                nan                nan
# 323              16.0                nan                nan
# 324              19.6               12.0                nan

# %% [markdown]
# # English

# %%
func_analyse_single_country(country = 'United States of America')
# Out:
# United States of America
#           Date               CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 512 2020-04-04  United States of America   31       1349.0            1201.7
# 513 2020-04-05  United States of America   32       1181.0            1234.7
# 514 2020-04-06  United States of America   33       1181.0            1237.0
# 515 2020-04-07  United States of America   34       1938.0            1433.3
# 516 2020-04-08  United States of America   35       1873.0            1664.0
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 512             904.3              572.8              392.5
# 513            1007.1              648.2              448.2
# 514            1103.0              727.5              503.9
# 515            1265.0              851.4              595.3
# 516            1396.9              969.1              683.4

# %%
func_analyse_single_country(country = 'United Kingdom')
# Out:
# United Kingdom
#           Date     CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 476 2020-04-04  United Kingdom   25        704.0             658.7
# 477 2020-04-05  United Kingdom   26        576.0             655.3
# 478 2020-04-06  United Kingdom   27        439.0             573.0
# 479 2020-04-07  United Kingdom   28        854.0             623.0
# 480 2020-04-08  United Kingdom   29      -5547.0           -1418.0
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 476             478.3              295.3              207.0
# 477             529.7              333.0              233.7
# 478             566.7              360.5              253.7
# 479             631.3              415.3              293.6
# 480            -243.1               16.1               27.9

# %%
func_analyse_single_country(country = 'Canada')
# Out:
# Canada
#          Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 73 2020-04-04      Canada   15         44.0              40.7
# 74 2020-04-05      Canada   16         49.0              47.3
# 75 2020-04-06      Canada   17         43.0              45.3
# 76 2020-04-07      Canada   18         57.0              49.7
# 77 2020-04-08      Canada   19         55.0              51.7
#
#     DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 73              24.6               15.2                nan
# 74              31.3               18.6                nan
# 75              33.4               21.4                nan
# 76              40.6               25.2                nan
# 77              46.6               28.6                nan

# %%
func_analyse_single_country(country = 'Australia')
# Out:
# Australia
#          Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 29 2020-04-04   Australia   13          2.0               3.0
# 30 2020-04-05   Australia   14          5.0               3.7
# 31 2020-04-06   Australia   15          6.0               4.3
# 32 2020-04-07   Australia   16          7.0               6.0
# 33 2020-04-08   Australia   17          2.0               5.0
#
#     DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 29               2.3                nan                nan
# 30               2.7                2.0                nan
# 31               3.3                2.4                nan
# 32               4.1                2.9                nan
# 33               4.1                2.9                nan

# %%
func_analyse_single_country(country = 'France')
# Out:
# France
#           Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 199 2020-04-04      France   30        441.0             500.0
# 200 2020-04-05      France   31        357.0             462.0
# 201 2020-04-06      France   32        605.0             467.7
# 202 2020-04-07      France   33        597.0             519.7
# 203 2020-04-08      France   34        541.0             581.0
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 199             459.7              352.6              259.2
# 200             469.0              370.2              276.2
# 201             495.7              398.8              302.7
# 202             508.1              426.4              329.6
# 203             514.3              444.9              349.3

# %%
func_analyse_single_country(country = 'Germany')
# Out:
# Germany
#           Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 221 2020-04-04     Germany   18        192.0             217.3
# 222 2020-04-05     Germany   19        123.0             162.7
# 223 2020-04-06     Germany   20        162.0             159.0
# 224 2020-04-07     Germany   21        140.0             141.7
# 225 2020-04-08     Germany   22        328.0             210.0
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 221             149.6               95.3                nan
# 222             156.9              102.9                nan
# 223             170.4              113.6                nan
# 224             175.1              121.5                nan
# 225             200.7              143.4              101.3

# %%
func_analyse_single_country(country = 'Sweden')
# Out:
# Sweden
#           Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 419 2020-04-04      Sweden    8         30.0              37.7
# 420 2020-04-05      Sweden    9         28.0              33.7
# 421 2020-04-06      Sweden   10         71.0              43.0
# 422 2020-04-07      Sweden   11        100.0              66.3
# 423 2020-04-08      Sweden   12         92.0              87.7
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 419              33.9                nan                nan
# 420              36.7                nan                nan
# 421              41.9                nan                nan
# 422              52.1                nan                nan
# 423              57.7                nan                nan

# %% [markdown]
# # Portuguese

# %%
func_analyse_single_country(country = 'Brazil')
# Out:
# Brazil
#          Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 53 2020-04-04      Brazil   16         73.0              64.0
# 54 2020-04-05      Brazil   17         54.0              62.3
# 55 2020-04-06      Brazil   18         67.0              64.7
# 56 2020-04-07      Brazil   19        114.0              78.3
# 57 2020-04-08      Brazil   20        133.0             104.7
#
#     DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 53              45.4               29.6                nan
# 54              50.0               32.9                nan
# 55              56.3               37.1                nan
# 56              66.6               44.4                nan
# 57              80.0               53.1                nan

# %%
func_analyse_single_country(country = 'Portugal')
# Out:
# Portugal
#           Date CountryName  day  DailyDeaths  DailyDeaths_MA_3  \
# 340 2020-04-04    Portugal   15         20.0              26.3
# 341 2020-04-05    Portugal   16         29.0              28.7
# 342 2020-04-06    Portugal   17         16.0              21.7
# 343 2020-04-07    Portugal   18         34.0              26.3
# 344 2020-04-08    Portugal   19         35.0              28.3
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21
# 340              23.7               18.1                nan
# 341              25.1               20.1                nan
# 342              24.4               20.6                nan
# 343              26.4               22.3                nan
# 344              27.6               24.1                nan

# %% [markdown]
# # Final thoughts - analysing Confirmed vs Deaths rate

# %%
df_lastday = df[df['Date'] == df['Date'].max()]
df_lastday.head()
# Out:
#    CountryName       Date  Confirmed  Deaths  DailyDeaths  DailyConfirmed  \
# 15   Argentina 2020-04-08     1314.0    66.0          5.0          -580.0
# 33   Australia 2020-04-08     6024.0    50.0          2.0           105.0
# 36     Bolivia 2020-04-08      244.0     8.0         -1.0            99.0
# 57      Brazil 2020-04-08    15927.0   800.0        133.0          2210.0
# 77      Canada 2020-04-08    19261.0   435.0         55.0          1391.0
#
#    OutbreakStartDate  day  DailyDeaths_MA_3  DailyDeaths_MA_7  \
# 15        2020-03-24   15               6.7               4.7
# 33        2020-03-22   17               5.0               4.1
# 36        2020-03-30    9               nan               nan
# 57        2020-03-19   20             104.7              80.0
# 77        2020-03-20   19              51.7              46.6
#
#     DailyDeaths_MA_14  DailyDeaths_MA_21
# 15                4.1                nan
# 33                2.9                nan
# 36                nan                nan
# 57               53.1                nan
# 77               28.6                nan

# %%
df_lastday['ConfirmedDeathsRate'] = df_lastday['Confirmed']/df_lastday['Deaths']
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_lastday.sort_values('ConfirmedDeathsRate')
# Out:
#                   CountryName       Date  Confirmed  Deaths  DailyDeaths  \
# 203                    France 2020-04-08        0.0  7632.0        541.0
# 284                     Italy 2020-04-08   139422.0 17669.0        542.0
# 410                     Spain 2020-04-08   146690.0 14555.0        757.0
# 423                    Sweden 2020-04-08     7783.0   619.0         92.0
# 480            United Kingdom 2020-04-08     9977.0   689.0      -5547.0
# 324                    Mexico 2020-04-08     3181.0   174.0         33.0
# 57                     Brazil 2020-04-08    15927.0   800.0        133.0
# 15                  Argentina 2020-04-08     1314.0    66.0          5.0
# 155                     China 2020-04-08    75449.0  3274.0         -7.0
# 450               Switzerland 2020-04-08    13892.0   541.0       -285.0
# 309                  Malaysia 2020-04-08     4119.0   156.0        -14.0
# 516  United States of America 2020-04-08   422363.0 14464.0       1873.0
# 36                    Bolivia 2020-04-08      244.0     8.0         -1.0
# 344                  Portugal 2020-04-08    13141.0   380.0         35.0
# 77                     Canada 2020-04-08    19261.0   435.0         55.0
# 239                     India 2020-04-08     4352.0    92.0          7.0
# 377               South Korea 2020-04-08     8249.0   165.0         44.0
# 225                   Germany 2020-04-08   110355.0  2151.0        328.0
# 33                  Australia 2020-04-08     6024.0    50.0          2.0
#
#      DailyConfirmed OutbreakStartDate  day  DailyDeaths_MA_3  \
# 203             0.0        2020-03-05   34             581.0
# 284          3836.0        2020-02-24   44             594.0
# 410          6180.0        2020-03-07   32             712.3
# 423           660.0        2020-03-27   12              87.7
# 480        -45265.0        2020-03-10   29           -1418.0
# 324           396.0        2020-03-25   14              26.7
# 57           2210.0        2020-03-19   20             104.7
# 15           -580.0        2020-03-24   15               6.7
# 155          -659.0        2020-01-22   77              -1.0
# 450         -8949.0        2020-03-13   26             -63.0
# 309           156.0        2020-03-03   36              -7.7
# 516         30514.0        2020-03-04   35            1664.0
# 36             99.0        2020-03-30    9               nan
# 344           699.0        2020-03-20   19              28.3
# 77           1391.0        2020-03-20   19              51.7
# 239            11.0        2020-03-26   13              19.0
# 377         -1429.0        2020-02-24   44               7.7
# 225          6872.0        2020-03-17   22             210.0
# 33            105.0        2020-03-22   17               5.0
#
#      DailyDeaths_MA_7  DailyDeaths_MA_14  DailyDeaths_MA_21  \
# 203             514.3              444.9              349.3
# 284             644.9              726.1              699.6
# 410             786.0              794.4              664.6
# 423              57.7                nan                nan
# 480            -243.1               16.1               27.9
# 324              19.6               12.0                nan
# 57               80.0               53.1                nan
# 15                4.7                4.1                nan
# 155               5.6                4.5                5.0
# 450               3.3               25.3               24.0
# 309               2.0               -1.1                1.6
# 516            1396.9              969.1              683.4
# 36                nan                nan                nan
# 344              27.6               24.1                nan
# 77               46.6               28.6                nan
# 239              11.7                nan                nan
# 377               5.6                5.1                6.1
# 225             200.7              143.4              101.3
# 33                4.1                2.9                nan
#
#      ConfirmedDeathsRate
# 203                  0.0
# 284                  7.9
# 410                 10.1
# 423                 12.6
# 480                 14.5
# 324                 18.3
# 57                  19.9
# 15                  19.9
# 155                 23.0
# 450                 25.7
# 309                 26.4
# 516                 29.2
# 36                  30.5
# 344                 34.6
# 77                  44.3
# 239                 47.3
# 377                 50.0
# 225                 51.3
# 33                 120.5

# %%
germany_ConfirmedDeathsRate = float(df_lastday[df_lastday['CountryName']=='Germany']['ConfirmedDeathsRate'])
float(df_lastday[df_lastday['CountryName']=='Germany']['ConfirmedDeathsRate'])
# Out:
# 51.30404463040446

# %%
print ("In germany the overall death rate is {}%".format(100/germany_ConfirmedDeathsRate))
# Out:
# In germany the overall death rate is 1.9491640614380863%

# %%
df_lastday['ConfirmedEstimated'] = df_lastday['Deaths'] * germany_ConfirmedDeathsRate
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_lastday[['CountryName','Date','Confirmed','Deaths','ConfirmedEstimated']]
# Out:
#                   CountryName       Date  Confirmed  Deaths  \
# 15                  Argentina 2020-04-08     1314.0    66.0
# 33                  Australia 2020-04-08     6024.0    50.0
# 36                    Bolivia 2020-04-08      244.0     8.0
# 57                     Brazil 2020-04-08    15927.0   800.0
# 77                     Canada 2020-04-08    19261.0   435.0
# 155                     China 2020-04-08    75449.0  3274.0
# 203                    France 2020-04-08        0.0  7632.0
# 225                   Germany 2020-04-08   110355.0  2151.0
# 239                     India 2020-04-08     4352.0    92.0
# 284                     Italy 2020-04-08   139422.0 17669.0
# 309                  Malaysia 2020-04-08     4119.0   156.0
# 324                    Mexico 2020-04-08     3181.0   174.0
# 344                  Portugal 2020-04-08    13141.0   380.0
# 377               South Korea 2020-04-08     8249.0   165.0
# 410                     Spain 2020-04-08   146690.0 14555.0
# 423                    Sweden 2020-04-08     7783.0   619.0
# 450               Switzerland 2020-04-08    13892.0   541.0
# 480            United Kingdom 2020-04-08     9977.0   689.0
# 516  United States of America 2020-04-08   422363.0 14464.0
#
#      ConfirmedEstimated
# 15               3386.1
# 33               2565.2
# 36                410.4
# 57              41043.2
# 77              22317.3
# 155            167969.4
# 203            391552.5
# 225            110355.0
# 239              4720.0
# 284            906491.2
# 309              8003.4
# 324              8926.9
# 344             19495.5
# 377              8465.2
# 410            746730.4
# 423             31757.2
# 450             27755.5
# 480             35348.5
# 516            742061.7

# %% [markdown]
# ## Question 1 - how could we estimate the number of cases? what else could we do?
# survey style testing?
#
#
# ## Question 2 - how could we predict the future of the trend?

# %% [markdown]
# ---

# %% [markdown]
# Can we do a better model than https://videos.elmundo.es/v/0_jiyz8faj-las-estadisticas-de-jano-garcia-las-muertes-bajaran-drasticamente-a-partir-del-20-de-abril?count=0?
